# %% [markdown]
# <a href="https://colab.research.google.com/github/shi5a/Data-Science-Bootcamp/blob/main/ML_Week2_DecisionTree_AirlinesDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Group Members :
#
#
# Shaikha AlBilais
#
# Sarah Alhugail
#
# Eatidal Almutairi
#
# Hailah Alharthi

# %% [markdown]
# # Decision Tree Assignment
#
# #### Deleverables
# - EDA
#     - Tell / show me about your data
#     - Etc...
# - Data prep / wrangling
#     - pick & prep your features
#     - [train_test_split()](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)
#     - Etc...
# - Model
#     - Import and make a [DecisionTreeClassifier()](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)
#     - Bonus: [GridSearchCV()](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) or [RandomizedSearchCV()](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html)
#     - Bonus: [RandomForestClassifier()](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)
#         - Explain what's going on..
# - Score your model
#     - Accuracy
#     - Confusion matrix
#     - Etc...
# - Display your decision tree with [plot_tree()](https://scikit-learn.org/stable/modules/generated/sklearn.tree.plot_tree.html) (or similar)
#     - Explain your tree
#     - Etc...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import *
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import *
sns.set_palette('Set2')
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # EDA

# %%
df = pd.read_parquet('https://github.com/gumdropsteve/datasets/raw/master/airlines.parquet')

df.head()
# Out:
#    ArrDelayBinary  t_Year  t_Month  ...   Dest  Distance  Diverted
# 0               0  1991.0      8.0  ...  244.0     110.0       0.0
# 1               0  1990.0     11.0  ...   11.0     595.0       0.0
# 2               0  1991.0      1.0  ...  175.0     412.0       0.0
# 3               0  1991.0      6.0  ...   11.0     545.0       0.0
# 4               0  1988.0     10.0  ...  171.0     866.0       0.0
#
# [5 rows x 14 columns]

# %%
df.shape
# Out:
# (4000000, 14)

# %% [markdown]
# Target is `ArrDelayBinary`.

# %%
df.ArrDelayBinary.value_counts()
# Out:
# 0    3307255
# 1     692745
# Name: ArrDelayBinary, dtype: int64

# %%
df.drop(['Diverted'],axis=1, inplace=True)

# %%
corr= df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_213120d6_695b_11eb_953b_0242ac1c0002row0_col0,#T_213120d6_695b_11eb_953b_0242ac1c0002row1_col1,#T_213120d6_695b_11eb_953b_0242ac1c0002row2_col2,#T_213120d6_695b_11eb_953b_0242ac1c0002row3_col3,#T_213120d6_695b_11eb_953b_0242ac1c0002row4_col4,#T_213120d6_695b_11eb_953b_0242ac1c0002row5_col5,#T_213120d6_695b_11eb_953b_0242ac1c0002row6_col6,#T_213120d6_695b_11eb_953b_0242ac1c0002row7_col7,#T_213120d6_695b_11eb_953b_0242ac1c0002row8_col8,#T_213120d6_695b_11eb_953b_0242ac1c0002row9_col9,#T_213120d6_695b_11eb_953b_0242ac1c0002row10_col10,#T_213120d6_695b_11eb_953b_0242ac1c0002row11_col11,#T_213120d6_695b_11eb_953b_0242ac1c0002row12_col12{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_213120d6_695b_11eb_953b_0242ac1c0002row0_col1,#T_213120d6_695b_11eb_953b_0242ac1c0002row1_col12{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_213120d6_695b_11eb_953b_0242ac1c0002row0_col2,#T_213120d6_695b_11eb_953b_0242ac1c0002row0_col12,#T_213120d6_695b_11eb_953b_0242ac1c0002row3_col2,#T_213120d6_695b_11eb_953b_0242ac1c0002row4_col1,#T_213120d6_695b_11eb_953b_0242ac1c0002row6_col2,#T_213120d6_695b_11eb_953b_0242ac1c0002row11_col2,#T_213120d6_695b_11eb_953b_0242ac1c0002row12_col2{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_213120d6_695b_11eb_953b_0242ac1c0002row0_col3,#T_213120d6_695b_11eb_953b_0242ac1c0002row5_col4,#T_213120d6_695b_11eb_953b_0242ac1c0002row6_col4,#T_213120d6_695b_11eb_953b_0242ac1c0002row7_col9,#T_213120d6_695b_11eb_953b_0242ac1c0002row9_col4,#T_213120d6_695b_11eb_953b_0242ac1c0002row10_col5,#T_213120d6_695b_11eb_953b_0242ac1c0002row12_col7{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_213120d6_695b_11eb_953b_0242ac1c0002row0_col4,#T_213120d6_695b_11eb_953b_0242ac1c0002row0_col11,#T_213120d6_695b_11eb_953b_0242ac1c0002row1_col11,#T_213120d6_695b_11eb_953b_0242ac1c0002row2_col3,#T_213120d6_695b_11eb_953b_0242ac1c0002row3_col4,#T_213120d6_695b_11eb_953b_0242ac1c0002row4_col3,#T_213120d6_695b_11eb_953b_0242ac1c0002row4_col6,#T_213120d6_695b_11eb_953b_0242ac1c0002row5_col3,#T_213120d6_695b_11eb_953b_0242ac1c0002row6_col3,#T_213120d6_695b_11eb_953b_0242ac1c0002row8_col0,#T_213120d6_695b_11eb_953b_0242ac1c0002row8_col6,#T_213120d6_695b_11eb_953b_0242ac1c0002row10_col6{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_213120d6_695b_11eb_953b_0242ac1c0002row0_
plt.figure(figsize=(10,6))

sns.lineplot(data=df, x= 't_Year', y='ArrDelayBinary').set_title('Delay Over Years');

# %%
plt.figure(figsize=(10,6))


sns.scatterplot(x= 'Distance',y= 'ActualElapsedTime' , hue ='ArrDelayBinary', data = df ).set_title('Realtionship between the Distance and Actual Elapsed time  ');

# %% [markdown]
# ## Data prep / wrangling

# %%
df.isna().sum()
# Out:
# ArrDelayBinary       0
# t_Year               0
# t_Month              0
# DayofMonth           0
# DayofWeek            0
# CRSDepTime           0
# CRSArrTime           0
# UniqueCarrier        0
# FlightNum            0
# ActualElapsedTime    0
# Origin               0
# Dest                 0
# Distance             0
# dtype: int64

# %% [markdown]
# # pick & prep your features

# %%
df.columns
# Out:
# Index(['ArrDelayBinary', 't_Year', 't_Month', 'DayofMonth', 'DayofWeek',
#        'CRSDepTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum',
#        'ActualElapsedTime', 'Origin', 'Dest', 'Distance'],
#       dtype='object')

# %%
from sklearn.model_selection import  train_test_split
X = df[['ActualElapsedTime','CRSArrTime']]
y = df.ArrDelayBinary

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=7)

# %% [markdown]
# # Model Aplications
#
# *DecisionTreeClassifier()*

# %%
tree = DecisionTreeClassifier(max_depth=5) # we minimize the depth to make the plot more clear , we had accurcy 87% with defult setting

tree.fit(X, y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=5, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
tree.feature_importances_
# Out:
# array([0.76181396, 0.23818604])

# %%
preds = tree.predict(X_test)
preds
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
accuracy_score(y_test, preds)
# Out:
# 0.8272225

# %%
plot_confusion_matrix(tree, X_test, y_test , values_format='')

# %% [markdown]
# ## Display your decision tree with plot_tree(), Explain your tree  ..

# %%
plt.figure(figsize=(40,20))
plot_tree(tree, feature_names= ['CRSArrTime',  'ActualElapsedTime'],fontsize=15,filled=True, rounded=True);
plt.title('Decision Tree', fontsize=18);

# %% [markdown]
# **we minimized the depth to make the plot more clear , we had accurcy 87% with defult setting , As we see CRSarrTime has more effect on decision of the model and we have gini 0.286**

# %% [markdown]
# # Bonus: RandomizedSearchCV()

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform

distributions = dict( max_depth=[2,5,9], min_samples_leaf= [2,4,6])


clf = RandomizedSearchCV(tree,distributions)

# %%
search = clf.fit(X_train, y_train)
search
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:281: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# RandomizedSearchCV(cv=None, error_score=nan,
#                    estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=5,
#                                                     max_features=None,
#                                                     max_leaf_nodes=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
#                                                     min_weight_fraction_leaf=0.0,
#                                                     presort='deprecated',
#                                                     random_state=None,
#                                                     splitter='best'),
#                    iid='deprecated', n_iter=10, n_jobs=None,
#                    param_distributions={'max_depth': [2, 5, 9],
#                                         'min_samples_leaf': [2, 4, 6]},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring=None, verbose=0)

# %%
search.best_params_
# Out:
# {'max_depth': 9, 'min_samples_leaf': 6}

# %% [markdown]
# ## Adjusting DecisionTreeClassifier parameters

# %%
treeS = DecisionTreeClassifier(max_depth=9, min_samples_leaf= 2)

treeS.fit(X, y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=9, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=2, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
treeS.feature_importances_
# Out:
# array([0.71973473, 0.28026527])

# %%
preds = treeS.predict(X_test)
preds
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
accuracy_score(y_test, preds)
# Out:
# 0.82761875

# %%
plot_confusion_matrix(treeS, X_test, y_test , values_format='')

# %% [markdown]
# # conclusion :
#
# **we got hieghr score after applying RandomizedSearchCV prameters on DecisionTreeClassifier Models**
